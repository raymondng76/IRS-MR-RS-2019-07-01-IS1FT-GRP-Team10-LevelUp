# %% [markdown]
# # data preparation

# %%
import pandas as pd
data = pd.read_excel('job_classification_data.xlsx')
x = data['titles'].tolist()
y = data['description'].tolist()

# %%
x
# Out:
# ['data analyst junior',
#  'data analyst senior ',
#  'business analyst',
#  'software engineer  junior',
#  'software engineer  senior',
#  'software manager',
#  'software director',
#  'project manager',
#  'sales manager']

# %%
y
# Out:
# ['"JOB DESCRIPTION\n\t\t\t \xa0Data Analyst, Group Customer Analytics & Decisioning\xa0\xa0About OCBCHaving purpose and making a real impact drives what we do at OCBC, for our customers, colleagues and the community. People count on us to deliver an amazing banking experience, but more importantly one that is uncomplicated and complements their changing lifestyle and business needs. Our employees are the architects that make this all possible; they are high performing individuals and teams, experts in their field and above all believe in our purpose and commitment to customers.Our community of game changers at OCBC builds for the future; think Ambitious goals, act with a strong Belief and execute with Courage and agility to drive impact. These ABCs sit at the centre of our culture of change and innovation.\xa0\xa0What you’ll doWork with specific client groups in the Consumer Bank to understand their business challenges & identify areas where Customer analytics techniques could help them overcome these challenges and realise new opportunitiesDesign and deploy data pipelines & solutions to increase productivity of the Consumer Banking businessSupport planning, development, execution and tracking of Data Driven Marketing activity across all channelsDevelop data-driven actionable customer insights to support marketing, sales and service communications.\xa01.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Generate actionable customer insight to improve key business outcomes\xa0Support the deployment of world-class marketing analytics capabilities and practices to improve marketing effectiveness and efficiency of the OCBC Consumer Financial Services division. This includes:\xa01. Development and execution of marketing campaigns & event triggers to support customer acquisition, cross & upselling and account activation goals within the Consumer Banking business.2. Conducting data discovery and other data exploration activities to identify emerging trends and business opportunities.3. Developmentand ongoing management of campaign reporting, analysis and derivation of key customer metrics.4. Design of management reporting & visualization using Qlikview.5. Provision of ongoing support to segment and product management in the profiling and segmentation of customers as well as conduct of tactical mining to support their business initiatives.6. Regular interaction with product and segment managers to understand their business objectives. Proactive recommendation on how you think analytics could help them achieve their goals.\xa0\xa02.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Deploy,WORK LOCATION\t\t\t\t\t\t\t\t\t\tView larger map / directions\t\t\t\t\t\t\tView larger map\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\tNearby Transportations\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tRaffles Place MRT\n\t\t\t\t\n\t\t\t\t  \t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\tAddress\t\t\t\t\n\t\t\t\t65 Chulia Street Singapore"\n"JOB DESCRIPTION\n\t\t\t Inventory & Data Analyst –Asia (1 Year Contract)\xa0Responsibilities:Validation of data pulled by IT team against local country source files. Working with country and IT to resolve any data discrepancies.Review country daily inventory and working with planners to resolve any outliers.Managing reports from country to consolidate with daily inventory.Refresh daily inventory dashboard and work on any enhancements as needed.Weekly and monthly Supply Chain reports by divisions.Working on Excess inventory consolidationDeveloping and implementing RPA Projects:Monthly APAC Inventory QV.Parameters – Safety stock and stocking optimizer.Data consolidation for dashboardsPulling data to refresh monthly charts.Weekly and monthly Supply Chain reports by divisions.,WORK LOCATION\t\t\t\t\t\t\t\t\t\tView larger map / directions\t\t\t\t\t\t\tView larger map\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t \n\t\t\t\t\t\t\t\t\ ...
#  '"JOB DESCRIPTION\n\t\t\t Responsibilities:Manage the processes and people responsible for accurate data collection, processing, modeling and analysis.Complete life cycle data generation and outline critical information for each Project Manager.Ensure data accuracy and consistent reporting by designing and creating optimal processes and procedures for analytics team to followAcquire data from primary or secondary data sources and maintain databases/data systems.Develop and implement databases, data collection systems, data analytics and other strategies that optimize statistical efficiency and qualityUse statistical methods to analyze data and generate useful business reportUse data to create models that depict trends in the customer base and the consumer population as a wholeOwn and maintain all dashboards, ongoing reporting reports, and ad hoc requests from the organization\xa0Requirements:Degree in Computer Science, Mathematics etc.2+ years’ Data mining experience, 4+ years in a data analyst roleStrong in data models, database design development, data mining and segmentation techniquesProficiency in using query languages such as SQL, Hive, PigExperience with ERwin Data Modeler V7 or a comparable data modeling tool,Oracle, MSSQL, MYSQL database technologies, AWS/RDS, RedshiftExperience with enterprise data management technologies, including database platforms, ETL tools, and SQLFamiliar with at least two of Tableau, Microstrategy, Qlikview, Informatica, ORACLE BI tools.Experience using statistical computer languages (Python, SQL,R, C++, JAVA etc.) to manipulate data and draw insights from large data sets.Knowledge of a variety of machine learning techniques (clustering, decision tree learning, artificial neural networks, etc.) and their real-world advantages/drawback\xa0Candidates with relevant experience, please send your resume in MS Word format to AIRENE:airene.r@scientecpersonnel.com\xa0Please include the following:• Current salary• Expected salary• Notice period• Reasons for leaving each company\xa0By submitting any application or resume to us, you will be deemed to have agreed & consented to us collecting, using, retaining & disclosing your personal information to prospective employers for their consideration.\xa0Resquid Airene Quitaleg (R1656137)ScienTec Consulting Pte Ltd (ScienTec Personnel) - 11C5781"\n"JOB DESCRIPTION\n\t\t\t • Position: Manager (Data Analytics)• Employment type: Permanent• Location: CentralJob ResponsibilitiesWork with auditors and external stakeholders (Business and IT) to obtain understanding of business, processes and systems, perform data analysis to support auditors’ work and improve quality of audits.Perform data analysis and visualisation on large-scale datasets, and present analytical insights on higher risk areas.Design dashboards and interactive visualisation as tools for data exploration, as well as for storytelling.Required AttributesIn-depth knowledge of basic data science concepts (e.g. machine learning algorithms, natural language processing, business application of statistics), data mining and knowledge discovery, text mining/ text analytics.Technical expertise in data analysis technologies (e.g. Tableau, Python, R, SAS).Able to work independently, a good team player and resourceful with good interpersonal and communication skills.Professional working experience in data science, business analytics or a related field would be an advantage.\xa0This position is only open to Singaporeans.\xa0\xa0If keen, kindly forward your resume/application to ssso@scientecsearch.com\xa0Do please note that only shortlisted candidates will be contacted.\xa0By submitting any application or resume to us, you will be deemed to have agreed & consented to us collecting, using, retaining & disclosing your personal information to prospective employers for their consideration. ScienTec is part of Will Group (https://willgroup.co.jp/en/profile/group.html) and candidates\' applications may be used by our affi ...
#  '"JOB DESCRIPTION\n\t\t\t Business AnalystJob Description   You will be part of a team that handles the end to implementation and maintenance of business application systems in the Cabin Crew Division. You will work closely with end-users to automate various business processes by implementing IT solutions that align with business goals.   Key Responsibilities include:    Co-ordinate and collate business requirements from different departments; and consolidate business requirements for tender.Perform feasibility studies during initiation of new IT systems.Perform cost benefit analyses to determine if projects can be justified to obtain project approvals.Manage end to end project implementation activities ensuring project objectives and timelines are met.Involved in change management initiatives relating to business systems.Required Skills & Qualifications  A good bachelors degree in Information Technology, or Science, or Engineering.1 to 3 years of working experience in similar role preferredGood communications (oral and written) and presentation skills.A team player and able to interact with co-workers of all levels.Analytical, systematic and logical in problem definition and solving.Able to multi-task.,WORK LOCATION\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\tAddress\t\t\t\t\n\t\t\t\t25 Airline Road Singapore 819829"\n"JOB DESCRIPTION\n\t\t\t Close to mrt stationEnjoy a fair work-life balanceOpportunities for enhanced learningSummary:The role is responsible to gather, visualize and analyze master data and business process information of group of companies to identify opportunities of improvement for data optimization, cost reduction and process efficiency.\xa0 He/she is also responsible to collaborate with respective departments across group of companies for delivering realistic suggestions for to implement for improvements successfully.\xa0Accountabilities and Tasks:Gather information: Conduct surveys, gather data and produce documents for “as-in” business processes of group of companies.Analysis: Analyze and evaluate business process of company. Use this as platform for team to investigate company’s processes for further optimization.Investigation: Investigate and identify non-compliances or potential risks in business process. Also identify opportunities for improvement in term of costs reduction, productivity and business expansion.Implementation: Collaborate with respective department to develop and implement a “to-be” process plan or solution. Legal or compliance risk must be eliminated while other improvements shall be implemented for business sustainability.Follow up: In order to practice PDCA, check the effectiveness of implemented improvements for planning next steps.Reqiuirements:Candidate must possess at least a Bachelor\'s Degree, Post Graduate Diploma, Professional Degree, Finance/Accountancy/Banking, Business Studies/Administration/Management or equivalent.At least 3 year(s) of working experience in the related field is required for this position.Experience in implementing change initiatives.Diverse knowledge in end-to-end business process flow.A good experience in Oracle database will be an added advantage.How to Apply:Interested candidates, please submit your updated resume in MSWORD format by using Apply Now button or email to recruit@corestaff.com.sg\xa0We regret to inform that only shortlisted candidates will be informed.\xa0Ngu Hui LingRegistration No : R1217701EA License No : 18C9027"\n"JOB DESCRIPTION\n\t\t\t Up to $5500 + VBExperience in Banking/Finance/Insurance industryExperience in Trade Finance/System: Import/ExportFamiliar with Software Development Lifecycle (SDLC)Responsibilities\xa0Gather both user and system requirements from multiple stakeholdersPerform detailed gap analysis (As Is and To Be)Provide domain expertise & focus in the specific industryPropose alternative operational solution to improve and bring abo ...
#  '"JOB DESCRIPTION\n\t\t\t \xa0Candidate must be able to work within a team to carry out software development to support machine vision automation equipment\xa0ResponsibilitiesDesign and develop software for machine vision automation equipmentSortware development for GUI, SQLite, real time socket communicationInvolve in software development life cycle\xa0RequirementsDiploma/Degree in engineering disciplineProgramming skills in visual studio development environmentKnowledge in C# programming languageExperience in programming language such VB Macro, Visual Basic, Python,C++ would be advantage"\n"JOB DESCRIPTION\n\t\t\t J2EE Senior Software Engineer/\xa0 J2EE Senior Consultant ( 15 open positions available)\xa0Job Responsibilities:• Analyse, design, develop, implement and maintain application systems to support the Board’s schemes• Provide support to users of the IT application systems• Lead the project or assist the Project Manager to conceptualize, design, development and implement IT Projects\xa0MINIMUM REQUIREMENTS:• Minimally 8 years of experience in application development & maintenance and projects management in open systems environment• ‘Hands-on’ knowledge and experience in end-to-end Software Development Life Cycle, able to manage the scope of requirement, to review application design and to deliver cost effective solution to business users and external stakeholders• Possess strong technical knowledge in Java/JEE in design, development and maintenance of application systems• Good communication, strong analytical, problem solving and presentation skills\xa0Interested candidates, please submit your MS Word CV to: robianne.deguzman@experis.com.sgWe regret that only shortlisted candidates will be notified.De Guzman Robi AnneConsulting Manager\xa0\xa0 R1544992EA License No.: 02C3423,WORK LOCATION\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\tAddress\t\t\t\t\n\t\t\t\t1 Wallich Street #09-02 Guoco Tower Singapore 078881"\n"JOB DESCRIPTION\n\t\t\t • Nearby Matter MRT• Immediate full time position• Good in software development, designing and maintenance - related to transportation system\xa0\xa0Our Client is a business solutions firm who is inviting qualified candidates to fill the position as SoftwareEngineer.\xa0\xa0RESPONSIBILITIES:Maintain, improve, design and develop application software for transportation parking systemDevelop system enhancements and rectify technical issuesParticipate actively in system software audit activities.Resolve complex technical issues.Ensure codes are in compliance to standards.Ad-hoc technical support.REQUIREMENTS:Minimum Degree in Computer Science or related qualification3 years and above hands-on programming experience (C or C++ preferred)Good communication skills and able to write technical documentsFamiliar with Linux systems and common commandsHave done actual projects in minimum two automation systems and know how the full system worksGood working attitude and willing to learnOTHER INFORMATION:Location : MattarWorking days : Office hourSalary\xa0 : Salary will commensurate according to experience & qualificationsHOW TO APPLY:\xa0Interested candidate, please submit your detailed updated resume in MS WORD Format to Lo Wing Sam (EA Personnel Reg.No. R1877254):\xa0converge16@achievegroup.asia\xa0or call your friendly Consultant, Sam, at 6590 9877 or WhatApps 9854 6986 for a confidential discussion.\xa0Please indicate the below information in your resume:\xa0Current & Expected salaryReason(s) for leavingAvailability to commence workWe regret only short-listed candidate will be notified. All applications will be treated with the strictest confidence.By submitting any application or résumé to us, you will be deemed to have agreed and consented to us collecting, using, retaining and disclosing your personal information to prospective employers for their consideration.,WORK LOCATION\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\ ...
#  '"JOB DESCRIPTION\n\t\t\t An exciting opportunity to work with a leading digital product organisation as their Lead Software Engineer (Java/Node.js).\xa0Client Details\xa0Our client is a leading international organisation within the digital product space with strong presence in Singapore. They are looking to hire a Lead Software Engineer (Java/Node.js).\xa0Description\xa0As a Lead Software Engineer (Java/Node.js), you will be responsible for the following:Designing and developing highly scalable, reliable and fault tolerant systems while Translate business requirements into scalable and extensible design.Partnering with the product management team to define and execute the feature roadmap.Improving code quality, product execution and customer delight.Building and managing fully automated build/test/deployment environments.Profile\xa0As a successful applicant, you will have a degree in Computer Science or relevant field. You will have 10 years of experience as a programmer. You will have strong hands on programming experience in full-stack web-technologies such as JavaScript /Node.js and MongoDB. You will also have experience in programming on the android platform as well.\xa0Job OfferNewly Created RoleExcellent Working Environment,WORK LOCATION\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\tNearby Transportations\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tRaffles Place\n\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tClarke Quay\n\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tTelok Ayer\n\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tDowntown\n\t\t\t\t\n\t\t\t\t  \t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\tAddress\t\t\t\t\n\t\t\t\tOne Raffles Place Tower 2 #09-61 Singapore 048616"\n"JOB DESCRIPTION\n\t\t\t We are looking for AI Software Engineer, Robotic Process Automation Programmer and Web Developer, specialized in bootstrap in building web platforms for internal software development.\xa0Job ResponsibilityDesign HR softwareDesign ChatbotDevelop RPA scripts and platformBuild AI models and deploy the software into productionDesign any other softwareJob RequirementsDegree in Information TechnologyStrong hands-on programming skillsAble to work independentlyGood to have knowledge of Pyhthon, Natural Language Processing (NPL), SQL, Java, C++Interested of AI and RPA,WORK LOCATION\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t \n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\tNearby Transportations\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tNovena\n\t\t\t\t\n\t\t\t\t  \n\t\t\t\t\n\t\t\t\t\tNewton\n\t\t\t\t\n\t\t\t\t  \t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\tAddress\t\t\t\t\n\t\t\t\t51 Goldhill Plaza, #07-10/11, Singapore 308900"\n"JOB DESCRIPTION\n\t\t\t Responsibilities:Develop new applications / sub-modules in accordance to the technical and system design specifications for the businessMaintain and enhance the existing modules / applications and implement the system changes based on the functional specifications givenAnalyze and study the impact of user requests for new or modified programsResearch, propose and implement new methodology / framework / algorithm which will benefit the development processes as well as business goalsInteract extensively with internal /external business users to understand business issues and challenges for the business and translating these into technical specifications for system design and developmentProvide guidance to staff / system developers on system development and designProvide level 2 operational support for critical system in a 24/7 environmentProvide solution and architectural design of new systems’ requirements\xa0Requirements:Degree in Information Technology or equivalent3 years of programming experience and 1 year of project management experience\xa0Knowledge of Red Hat Fuse, JBoss Data Grid is an advantageSound technical knowledge in Java programming, Java Script, HTML, SQL, J2EE technologies, relational da ...
#  '"JOB DESCRIPTION\n\t\t\t \xa0\xa0We are seeking a highly driven individual to be part of our Information Technology Team. Reporting to the Assistant Director of Information Technology, the Principle/Senior Solution Architect will be responsible for establishing an Enterprise Architecture in driving business goals with leading edge technologies. \nAs a Digital Transformation change enabler, he/she is expected to understand complex business problems and commercial frameworks and how to apply a logical, systematic approach to arrive at an appropriate digital product, solution or service. He/she will be responsible for the formation and organizing of the IT Architectural Review Board in the IT Project Management Office, driving the technical cloud vision, implementation Hybrid API management and Data Analytics platforms for WRS. \nThe candidate must be able to work collaboratively with technical peers and appointed vendors on IT projects in providing technical direction on solution strategy and will also provide an oversight of technical delivery of all projects in IT Master Plan and assess change impact on inter-systems dependencies.\nRequirements:\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Degree in Computer Science, Software Engineering or Information Technology related fields.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Minimum 5 years\' experience in business application design, development, implementation, and/or enterprise/ solution architecture.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Previous experience in a Solution Design, Technical Lead or Architect Role within a digital environment delivering medium to large-scale digital transformation or software projects.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience of working across varied technology domains such as Cloud Technology, API management, Marketing Technology, Data Analytics and Cybersecurity.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Domain knowledge in the travel & attractions, hospitality, retail industry and/or financial services is highly beneficial.\nRequired Qualifications:\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Strong knowledge on software development methodologies like Waterfall and Agile (Scrum, Kan Ban).\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience of implementing architectural governance and proactively managing issues and risks throughout the delivery life cycle.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience in implementation and migration of systems/ applications in Azure hybrid cloud integration and on-premise critical systems deployment with continuous migration of on-premise workloads to cloud.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience in implementation of hybrid API management architecture and ESB application integration such as Mulesoft, Biztalk. \n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience in delivery of marketing technology stack such as Adobe Experience Cloud, e-Commerce, MS Dynamics 365 CRM, Marketing Automation Platform, Azure Active Directory B2C and integration with online payment gateway, onsite ticketing system and POS solutions.\xa0\xa0 \n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience in implementation of Azure Data Analytics Platform transforming structured data and unstructured data from multiple O2O sources, IoT and social sentiments into actionable insights.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Good familiarity with the disciplines of enterprise software development such as configuration & release management, source code & version controls management tools such as GitHub, GitLab and Team Foundation Server.\nPreferred Qualifications (added advantage):\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience with Microservices, container-based platforms and related deployment technologies to include Kubernetes, Docker and Serverless. \n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Applied knowledge on in Windows Server HA design Architecture design using HAProxy, Azure Load Balancer, Nutanix Hyperconverged Architecture and Cloudflare content delivery networks.\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Experience in native mobile app development for IOS a ...
#  '"JOB DESCRIPTION\n\t\t\t ✔ Up to S$11k/mth✔ China billion dollar company✔ Regional project exposure\xa0Job Descriptions\xa0• Work with external vendors, internal stakeholders and existing vendors in the development of the overall project schedule, including cutover plans, quality plans, budgets, change management plans, communication plans, and risk management plans• Manage all project related issues that may impact on scope, project schedule and cost.• Resolve issues arising from various components and sub-systems of the project including hardware, software, testing, business process review, redesign, application development, migration, data conversion, cutover etc.• Escalate and keep Senior Management informed of status and outstanding issues of the project on a regular and timely basis• Conduct briefing sessions to business partners who are impacted by this project to keep them updated to the progress of the project and seek necessary support from them.• Responsible for communicating with customers at different levels and developing the common milepost target, to promote customers (including office) to put the right resource into use, to promote the project implementation jointly and improve the customer satisfaction.•\xa0Responsible for making onsite customer plan, test, acceptance, migration and documentation plans with SC and engineering manager, and have the final decision on all relevant plans.• Coordinate and organise resources within relevant departments in the Company to participate, contribute and meeting the expected level of project requirements on a timely basis\xa0Requirements\xa0• Bachelor Degree in Computer Science/ Information Technology/ Engineering (Computer/Telecommunication• Minimum 10 years of working experiences in Telecom Domain handling OSS/BSS Projects with Cloud / IoT exposure• Willing to travel to Thailand• PMP certification preferred\xa0*To apply, contact 98221115 or send your CV/Resume to josephyap@recruitfirst.com.sg\xa0All applications will be treated with strictest confidentiality. We regret that only shortlisted candidates will be notified. Thank you.\xa0RecruitFirst Pte Ltd E.A. 13C6342Joseph Yap Shi Hao (R1767577)"\n"JOB DESCRIPTION\n\t\t\t Digital Arm of a Large CorporateInfluential Team Lead RoleExcellent Benefits and Competitive Package\xa0Responsibilities:Be the lighthouse to the software engineering culture, setting the baselines for the ideal software engineering environmentProvide leadership and direction to a team of software engineers in making Engineering Productivity a first priorityEstablish Processes necessary for Teams to be Agile (which is inclusive of Scrum, Kanban and XP)Establish Processes and Tools to develop quality software that is secure by designConceptualize Roadmap for Digital Infrastructure growthRecruit and develop software engineers, to help them advance in their careersWork with internal stakeholders\xa0 to balance and accommodate competing priorities\xa0Requirements:Developer-Turned-Manager preferably, or possess a strong understanding of Agile Engineering PrinciplesMin. 10 years\' software engineering experience including\xa05 years of Engineering Management experienceStrong Application Design, DevSecOps and Cloud experience (but prefer to lean on Leadership skills)Understand the importance of ""Engineering Productivity""A Pragmatic and Get Things Done mindsetThe ability to thrive on a high level of autonomy and responsibilityTo apply, please email your detailed CV in MS Word format to resumes@cadmusresources.com with the following details inside your CV for faster processing:\xa0Reason for leavingExpected salaryEarliest availability dateWe regret that only short-listed candidates will be contacted shortly."\n"JOB DESCRIPTION\n\t\t\t ResponsibilitiesRegional sales drive and management with marketing & sales strategies development, business planning and sales programAnalyze market dynamics, each country’s business challenges and develop specific strategies t ...
#  '"JOB DESCRIPTION\n\t\t\t As the Project Manager, your responsibilities include: -Ensure that all projects are delivered on-time, within scope and within budgetAssist in the definition of project scope and objectives, involving all relevant stakeholders and ensuring technical feasibilityEnsure resource availability and allocationDevelop a detailed project plan to monitor and track progressManage changes to the project scope, project schedule and project costs using appropriate verification techniquesMeasure project performance using appropriate tools and techniquesReport and escalate to management as neededManage the relationship with the client and all stakeholdersPerform risk management to minimize project risksEstablish and maintain relationships with third parties/vendorsCreate and maintain comprehensive project documentationMeet with clients to take detailed ordering briefs and clarify specific requirements of each projectDelegate project tasks based on junior staff members\' individual strengths, skill sets and experience levelsTrack project performance, specifically to analyze the successful completion of short and long-term goalsMeet budgetary objectives and make adjustments to project constraints based on financial analysisDevelop comprehensive project plans to be shared with clients as well as other staff membersUse and continually develop leadership skillsThe minimum requirements as follows:Proven working experience in project managementProject Management Professional (PMP) / PRINCE II / CITPM certification is a plusBachelor\'s Degree in appropriate field of study or equivalent work experienceExcellent client-facing and internal communication skillsExcellent written and verbal communication skillsSolid organizational skills including attention to detail and multitasking skillsStrong working knowledge of Microsoft OfficeExpertise in conflict resolutionExperience in Agile teams, DEVOPSProficiency with related software tools including but not limited to ProjectManager.com, JIRA, MS Excel, etc."\n"See who else has applied \n\t\n\t\t\t\t\t\t    \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tSave this job\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\tLeave your name card\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t \t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tApply Now\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t  \n\t\t\t\t\t\t      \n\t\t\t\t\t\t      Advertised: 10-August-2019\n\t\t\t\t\t\t\t  \n\t\t\t\t\t\t\t  \n\t\t\t\t\t\t\t  \n\t\t\t\t\t\t\t  \t\t\t\t\t\t\t  Closing on 30-August-2019"\n"JOB DESCRIPTION\n\t\t\t About BaxterBaxter provides a broad portfolio of essential renal and hospital products, including home, acute and in-centre dialysis; sterile IV solutions; infusion systems and devices; parenteral nutrition; surgery products and anaesthetics; and pharmacy automation, software and services. The company’s global footprint and the critical nature of its products and services play a key role in expanding access to healthcare in emerging and developed countries. Baxter’s employees worldwide are building upon the company’s rich heritage of medical breakthroughs to advance the next generation of healthcare innovations that enable patient care.\xa0What You’ll Be Doing\xa0We are looking for an experienced Programme Manager to join our Singapore-based Baxter team, working on a major Public Health disease management IT project.\xa0The Programme Manager will be responsible for the full project life cycle development and delivery of the Baxter ICNET software suite and will serve as primary liaison between the Singapore Baxter office, the UK Baxter office and  ...
#  '"JOB DESCRIPTION\n\t\t\t JD:• Responsible for team development & building as per business needs.• Responsible for Pre-Sales, training & support activities.• To Monitor Sales team in absence of Sales Head.• Work collaboratively with partners and customers to ensure their successful use of ANSYS products, sustain a renewals revenue stream and cultivate opportunities to expand software licenses.• Identifying targets for Technical support & sales business.• Accountable to direct employees in achieving targets.• Responsible to advice on strategy for growth of the organization.• Estimate market trends & strategically prepare the team.• Motivate, inspire the team to stay focused on company goals.• Maintain long lasting customer relationships.• Planning budget for new business areas in coordination with sales team.• Responsible to Prepare quarterly & yearly pre-sales business reports to analyze business performance.• Responsible for Front end business partnerships.• To Conduct & organize technical trainings as per Training Needs identified.• Building networks & developing alliances with ecosystem for generating business.• Coordinating with relevant technical and nontechnical resources at CADFEM India and CADFEM Germany for identifying and closing existing & new business opportunities.• Partner with the sales to• Review presales opportunities, forecast & pipeline• Clear roadblocks & advance opportunities• Develop ideas and support execution of NB growth initiatives• Personally engage with strategic customers to• Help create the SDPD solution vision• Drive SW Adoption• Continuously engage, collaborate and mentor juniors• Review of opportunities and help prioritization• Drive effectiveness and conversion• Drive adoption of tools (XChange, CRM)• Implement best practices (MEDDIC, Visit preparation/reports, documented Evaluation plans)• Mentor team – presales skills development\xa0Desired Candidate Profile:• Masters or Bachelor’s degree in engineering discipline• 5- 8 years of experience in demonstrated use of relevant ANSYS simulation software or knowledge of other commercial CAE software packages• Must have worked in APAC regions.• Looking for an individuals to work at Singapore, Thailand, Malaysia Locations.• Ability to orchestrate and organize complex system requirements.• Knowledge in industry standards and regulatory.• Ability to work independently, as well as with others in a diverse team environment.• Strong interpersonal and communication skills.• Demonstrated skills in writing and presenting in fluent English.• Logical problem-solving approach and the ability to clearly communicate the situation and proposed solution to the customer.• Projects a professional image and strong business acumen during customer interactions• Possesses a sense of urgency, strong organizational and follow up skills\xa0Interested candidates who wish to apply for the advertised position, please email us an updated copy of your resume.Email Address: sales@talenttradergroup.com\xa0EA License No: 13C6305Reg. No.: R1107014\xa0For candidate who applied for the advertised position is deemed to have consented to us that we may collect, use or disclose your personal information for purpose in connection with the services provided by us."\n"JOB DESCRIPTION\n\t\t\t \ufeffLocation: Jurong EastWorking hours: 9am - 6pm (Mon - Fri)Salary Range: Up to $7,500Industry: German MNC - AutomotiveThis is a Contract role (Immediate till 31st Dec 2019).Embed and drive Agile ceremonies, best practice and use of artifacts within all project teams, i.e. sprints, stand-ups, retro, show-and-tellWork closely with Product Owners in order to groom and proactively manage the respective backlogs and project timelinesEnsure that over-all value is delivered in terms of user stories, epics and releasesInterface with market Scrum Masters to report, track and ensure performance of local projectsContinuously ensure that relevant DevOps principles, tools and methodologies are applied throughout ...

# %% [markdown]
# # tf-idf Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=200000,
                                   stop_words='english',
                                   use_idf=True,
                                   max_df=0.8,min_df=0.2,
                                   ngram_range=(1,2))

tfidf_matrix = tfidf_vectorizer.fit_transform(y)

# %%
terms = tfidf_vectorizer.get_feature_names()
terms
# Out:
# ['00',
#  '01',
#  '01 asia',
#  '01 september',
#  '01 singapore',
#  '018960',
#  '018960 job',
#  '018989',
#  '018989 job',
#  '02',
#  '02 august',
#  '03',
#  '04',
#  '048616',
#  '048616 job',
#  '05',
#  '06',
#  '07',
#  '08',
#  '08c2893',
#  '08c2893 reg',
#  '08c2893karthiga',
#  '08c2893karthiga anandan',
#  '09',
#  '09 61',
#  '099453',
#  '10 01',
#  '10 marina',
#  '10 years',
#  '11',
#  '11 01',
#  '11 years',
#  '11c5781',
#  '12',
#  '124',
#  '124 143',
#  '13',
#  '13c6678to',
#  '13c6678to job',
#  '143',
#  '143 166',
#  '15',
#  '15 years',
#  '166',
#  '166 address',
#  '17',
#  '18',
#  '19',
#  '20',
#  '20 jalan',
#  '2019 job',
#  '24',
#  '25',
#  '31',
#  '365',
#  '3rd',
#  '3rd party',
#  '40',
#  '513',
#  '513 982e',
#  '5500',
#  '5k',
#  '5k aws',
#  '60',
#  '6000',
#  '61',
#  '61 124',
#  '61 singapore',
#  '6416',
#  '65',
#  '65 6416',
#  '6590',
#  '97',
#  '97 97e',
#  '97e',
#  '97e 513',
#  '982e',
#  '982e address',
#  'ability build',
#  'ability communicate',
#  'ability deal',
#  'ability deliver',
#  'ability explain',
#  'ability initiate',
#  'ability learn',
#  'ability manage',
#  'ability prioritise',
#  'ability travel',
#  'ability work',
#  'able develop',
#  'able effectively',
#  'able generate',
#  'able interact',
#  'able link',
#  'able multi',
#  'able network',
#  'able perform',
#  'able work',
#  'abreast',
#  'acceptance',
#  'acceptance testing',
#  'acceptance testingto',
#  'acceptance tests',
#  'access',
#  'access control',
#  'access website',
#  'accordance',
#  'accordance privacy',
#  'according',
#  'according business',
#  'according experience',
#  'account',
#  'account planning',
#  'accountability',
#  'accountable',
#  'accounting',
#  'accounts',
#  'accounts creating',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'achieve',
#  'achievegroup',
#  'achievegroup asia',
#  'achieving',
#  'achieving cost',
#  'acquisition',
#  'act',
#  'action',
#  'actionable',
#  'active',
#  'actively',
#  'activities existing',
#  'activities related',
#  'activity',
#  'actual',
#  'ad',
#  'ad hoc',
#  'adapt',
#  'adapt changes',
#  'addition',
#  'addition prepare',
#  'additional',
#  'address 10',
#  'address 20',
#  'address attended',
#  'address job',
#  'address marina',
#  'address ntuc',
#  'address raffles',
#  'address sales',
#  'address shenton',
#  'address singapore',
#  'addressing',
#  'adhere',
#  'administration',
#  'administration computer',
#  'administrative',
#  'administrator',
#  'administrator unix',
#  'adoption',
#  'adoption new',
#  'advance',
#  'advanced',
#  'advanced statistical',
#  'advanced technical',
#  'advantage experience',
#  'advantage job',
#  'advantage strong',
#  'advantage understanding',
#  'advantageous',
#  'advantages',
#  'advertised 02',
#  'advertised position',
#  'advice',
#  'advise',
#  'advising',
#  'advisory',
#  'advisory services',
#  'affiliates',
#  'affiliates accordance',
#  'afifi',
#  'afifi certis',
#  'aforementioned',
#  'aforementioned email',
#  'agile development',
#  'agile methodologies',
#  'agile methodology',
#  'agile project',
#  'agile scrum',
#  'agile software',
#  'agreed',
#  'agreed consented',
#  'agreed terms',
#  'agreement',
#  'agreements',
#  'ai',
#  'aim',
#  'airline',
#  'airline road',
#  'algorithms',
#  'align',
#  'aligned',
#  'alignment',
#  'alignment license',
#  'allocation',
#  'allow',
#  'alongside',
#  'alternative',
#  'alternative solutions',
#  'alternatives',
#  'alternatives time',
#  'analyse business',
#  'analyse data',
#  'analyse tender',
#  'analyses',
#  'analysis analyticscontinuously',
#  'analysis application',
#  'analysis capability',
#  'analysis etcproficient',
#  'analysis problem',
#  'analysis report',
#  'analysis requirements',
#  'analysis skills',
#  'analysis spot',
#  'analysis support',
#  'analysisdevelop',
#  'analyst',
#  'analyst business',
#  'analyst rolestrong',
#  'analysts',
#  'analytical aspects',
#  'analytical interpersonal',
#  'analytical model',
#  'analytical problem',
#  'analytical projectsexplore',
#  'analytical projectsidentify',
#  'analytical results',
#  'analytical self',
#  'analytical skill',
#  'analytical skills',
#  'analytics',
#  'analytics data',
#  'analytics equivalent',
#  'analytics related',
#  'analytics reporting',
#  'analytics requestsprovide',
#  'analytics statistics',
#  'analytics strategies',
#  'analytics techniques',
#  'analyticscontinuously',
#  'analyticscontinuously improve',
#  'analyze',
#  'analyze business',
#  'analyze trends',
#  'analyzing',
#  'anandan',
#  'anandan reg',
#  'android',
#  'ang',
#  'ang mo',
#  'angular',
#  'anlaysis',
#  'anlaysis related',
#  'ann',
#  'ant',
#  'anti',
#  'anticipate',
#  'apac',
#  'apache',
#  'api',
#  'api management',
#  'apis',
#  'app',
#  'app development',
#  'applicable',
#  'applicant',
#  'applicant degree',
#  'applicants contacted',
#  'applicants expect',
#  'applicants notified',
#  'applicants send',
#  'application advanced',
#  'application architecture',
#  'application deemed',
#  'application design',
#  'application development',
#  'application devices',
#  'application infrastructure',
#  'application integration',
#  'application position',
#  'application purposes',
#  'application resume',
#  'application résumé',
#  'application solution',
#  'application support',
#  'application systems',
#  'application technology',
#  'applications notified',
#  'applications responsible',
#  'applications support',
#  'applications treated',
#  'applied advertised',
#  'applied save',
#  'apply button',
#  'apply email',
#  'apply interested',
#  'apply job',
#  'apply online',
#  'apply position',
#  'apply send',
#  'apply shortlisted',
#  'apply statistical',
#  'applying',
#  'approach',
#  'approach require',
#  'approaches',
#  'approaches measurements',
#  'appropriate techniques',
#  'approved',
#  'approximately',
#  'apps',
#  'apps ebs',
#  'appstech',
#  'appstech level',
#  'architect',
#  'architect join',
#  'architect product',
#  'architect team',
#  'architects',
#  'architectural',
#  'architectural design',
#  'architecture',
#  'architecture ability',
#  'architecture business',
#  'architecture design',
#  'architecture implementation',
#  'architecture using',
#  'architectures',
#  'area',
#  'area specialization',
#  'areas data',
#  'areas improvements',
#  'areas technology',
#  'arising',
#  'articlespresent',
#  'articlespresent data',
#  'articulate',
#  'articulate analytical',
#  'artificial',
#  'artificial intelligence',
#  'asean3',
#  'asean3 base',
#  'asia pte',
#  'asia square',
#  'asia www',
#  'asp',
#  'asp net',
#  'aspects',
#  'aspects hospital',
#  'assess',
#  'assess relevant',
#  'assessing',
#  'assessment',
#  'asset',
#  'asset management',
#  'assigned',
#  'assigned requirements',
#  'assigned tasks',
#  'assignments',
#  'assigns',
#  'assist',
#  'assist software',
#  'assistant',
#  'assistant director',
#  'assistant manager',
#  'associated',
#  'associates',
#  'assurance',
#  'assurance tax',
#  'asynchronous',
#  'attended',
#  'attended address',
#  'attention',
#  'attention kara',
#  'attention kny',
#  'attitude',
#  'attn',
#  'attn jace',
#  'attn nazri',
#  'attractive',
#  'attractive remuneration',
#  'attributes',
#  'audit',
#  'audits',
#  'automate',
#  'automated',
#  'automated tests',
#  'automation software',
#  'automation tools',
#  'automotive',
#  'availability',
#  'available',
#  'avenue',
#  'avenue singapore',
#  'aws',
#  'aws ms',
#  'aws vb',
#  'ayer',
#  'ayer downtown',
#  'azure',
#  'azure administrator',
#  'ba',
#  'bachelors',
#  'background',
#  'backgrounds',
#  'backup',
#  'balance',
#  'balancer',
#  'bank',
#  'banking',
#  'banking business',
#  'banking industry',
#  'base',
#  'base key',
#  'base location',
#  'baselines',
#  'basic',
#  'basis',
#  'believe',
#  'believes',
#  'believes giving',
#  'belong',
#  'benchmarking',
#  'beneficial',
#  'benefit',
#  'benefit analysis',
#  'benefit risk',
#  'benefits competitive',
#  'best practice',
#  'best practices',
#  'best solution',
#  'better',
#  'better join',
#  'better visit',
#  'better working',
#  'bi',
#  'bi tool',
#  'bi tools',
#  'big',
#  'big data',
#  'billing',
#  'billion',
#  'biometric',
#  'biometric control',
#  'bit',
#  'bit ly',
#  'blue',
#  'board',
#  'bonus',
#  'boulevard',
#  'boulevard level',
#  'boulevard singapore',
#  'brand',
#  'bring',
#  'bring business',
#  'bringing',
#  'bringing significant',
#  'broad',
#  'broad knowledge',
#  'broad strategic',
#  'broad understanding',
#  'bs',
#  'bs computer',
#  'budget',
#  'budget resource',
#  'budgets',
#  'build',
#  'build better',
#  'build maintain',
#  'build test',
#  'building better',
#  'building web',
#  'builds',
#  'bus',
#  'bus 61',
#  'bus 97',
#  'business administration',
#  'business analysis',
#  'business analyst',
#  'business analytics',
#  'business application',
#  'business applications',
#  'business challenges',
#  'business consulting',
#  'business continuity',
#  'business cx',
#  'business data',
#  'business development',
#  'business domain',
#  'business environment',
#  'business expansion',
#  'business goals',
#  'business ideas',
#  'business information',
#  'business infra',
#  'business intelligence',
#  'business model',
#  'business needs',
#  'business needsto',
#  'business objectives',
#  'business offerings',
#  'business operation',
#  'business operations',
#  'business opportunities',
#  'business outcomes',
#  'business partners',
#  'business problems',
#  'business process',
#  'business processes',
#  'business product',
#  'business relationships',
#  'business requirements',
#  'business skills',
#  'business solution',
#  'business solutions',
#  'business stakeholders',
#  'business systems',
#  'business technical',
#  'business units',
#  'business user',
#  'business users',
#  'businesses',
#  'button',
#  'button confidential',
#  'button email',
#  'button regret',
#  'buy',
#  'buy solution',
#  'cadmusresources',
#  'cadmusresources com',
#  'caed',
#  'caed com',
#  'campaign',
#  'campus',
#  'candidate able',
#  'candidate applied',
#  'candidate bachelor',
#  'candidate interested',
#  'candidate notified',
#  'candidate possess',
#  'candidates contacted',
#  'candidates forward',
#  'candidates invited',
#  'candidates kindly',
#  'candidates send',
#  'candidates submit',
#  'candidates wish',
#  'capabilities',
#  'capability',
#  'capability analysis',
#  'capacity',
#  'capacity proficient',
#  'capita',
#  'capita pte',
#  'capital',
#  'capitasingapore',
#  'capitasingapore com',
#  'capture',
#  'care',
#  'career development',
#  'career edge',
#  'career freedom',
#  'career growth',
#  'career opportunities',
#  'career progression',
#  'career reference',
#  'careersbecome',
#  'careersbecome fan',
#  'carry',
#  'carry project',
#  'case',
#  'case studies',
#  'cases',
#  'cassandra',
#  'center',
#  'centers',
#  'central',
#  'central5',
#  'central5 working',
#  'centre',
#  'centre job',
#  'centre marina',
#  'certification',
#  'certification preferred',
#  'certifications',
#  'certifications itil',
#  'certified',
#  'certis',
#  'certis cisco',
#  'chain',
#  'chain retail',
#  'challenges',
#  'challenges customer',
#  'challenges develop',
#  'challenging',
#  'challenging offer',
#  'change management',
#  'change request',
#  'change requests',
#  'changes',
#  'changes project',
#  'changing',
#  'changing environment',
#  'changing industry',
#  'changing priorities',
#  'channel',
#  'channel encryption',
#  'channel partners',
#  'charge',
#  'charts',
#  'check',
#  'checks',
#  'china',
#  'chu',
#  'chu kang',
#  'cim',
#  'cisa',
#  'cisco',
#  'cisco centre',
#  'cissp',
#  'citpm',
#  'citpm job',
#  'citpm preferred',
#  'city',
#  'city tower',
#  'clarifications',
#  'clarifications ultimately',
#  'clarke',
#  'clarke quay',
#  'class',
#  'clear',
#  'clearly',
#  'clearly communicate',
#  'click',
#  'click apply',
#  'client details',
#  'client leading',
#  'client service',
#  'client utilizing',
#  'clients',
#  'close',
#  'close transaction',
#  'closely business',
#  'closely clients',
#  'closely product',
#  'closely team',
#  'closing 01',
#  'closing deals',
#  'closure',
#  'cloud',
#  'cloud business',
#  'cloud experience',
#  'cloud general',
#  'cloud like',
#  'cloud security',
#  'cloud technology',
#  'cms',
#  'coach',
#  'coach team',
#  'coaching',
#  'coaching feedback',
#  'code',
#  'code quality',
#  'codes',
#  'coding',
#  'coe',
#  'collaborate business',
#  'collaborates',
#  'collaboration',
#  'collaboration engagement',
#  'collaborative',
#  'collaborative team',
#  'collaboratively',
#  'collate',
#  'collaterals',
#  'colleagues',
#  'colleagues opportunities',
#  'collect',
#  'collect use',
#  'collecting',
#  'collecting using',
#  'collection',
#  'collection use',
#  'com attention',
#  'com copy',
#  'com ernstandyoungglobal',
#  'com eycareerssingaporefollow',
#  'com eysgcareersconnect',
#  'com following',
#  'com position',
#  'com sgwe',
#  'comea',
#  'comea license',
#  'comes',
#  'comfortable',
#  'comfortable working',
#  'commence',
#  'commence workwe',
#  'commensurate',
#  'commensurate according',
#  'commerce',
#  'commercial',
#  'commitment',
#  'committed',
#  'common',
#  'communicate effectively',
#  'communicate findings',
#  'communicating',
#  'communication including',
#  'communication interpersonal',
#  'communication presentation',
#  'communication writing',
#  'communications',
#  'community',
#  'companies',
#  'company global',
#  'company products',
#  'compare',
#  'compare alternative',
#  'compensation',
#  'compensation package',
#  'competencies',
#  'competency',
#  'competing',
#  'competitive compensation',
#  'competitive offerings',
#  'competitive package',
#  'competitive remuneration',
#  'competitor',
#  'complete',
#  'completed',
#  'completion',
#  'complex business',
#  'complex data',
#  'complex problems',
#  'complex software',
#  'complex technical',
#  'compliance',
#  'compliance standards',
#  'components',
#  'comprehensive',
#  'comprehensive resume',
#  'computer engineering',
#  'computer telecommunication',
#  'computing',
#  'concept',
#  'concept pilot',
#  'concepts',
#  'concepts data',
#  'concepts understanding',
#  'conceptualization',
#  'conceptualize',
#  'concurrent',
#  'conditions',
#  'conduct',
#  'conduct performance',
#  'conduct user',
#  'conducting',
#  'confidence',
#  'confidence submitting',
#  'confident',
#  'confident team',
#  'confidential',
#  'confidential discussion',
#  'confidentiality',
#  'configuration',
#  'configuration customization',
#  'conflicts',
#  'connection',
#  'connection job',
#  'connection services',
#  'consensus',
#  'consent',
#  'consent drop',
#  'consented',
#  'consented collect',
#  'consented collecting',
#  'consented collection',
#  'consider',
#  'consideration',
#  'consideration indicate',
#  'consideration job',
#  'consideration regret',
#  'consideration work',
#  'considerations',
#  'considered',
#  'consistency',
#  'consistent',
#  'consistently',
#  'consolidate',
#  'consolidation',
#  'constantly',
#  'constraints',
#  'consultancy',
#  'consultancy project',
#  'consultant',
#  'consultant industry',
#  'consultants',
#  'consultants capita',
#  'consultants ea',
#  'consulting',
#  'consulting business',
#  'consulting drives',
#  'consulting people',
#  'consulting pte',
#  'consulting sales',
#  'consulting services',
#  'consulting solution',
#  'consulting solutions',
#  'consumer',
#  'contact',
#  'contacted',
#  'contacted shortly',
#  'container',
#  'content',
#  'continual',
#  'continually',
#  'continuity',
#  'continuous',
#  'continuous improvement',
#  'continuous integration',
#  'continuously',
#  'contract',
#  'contract role',
#  'contractor',
#  'contracts',
#  'contractual',
#  'contractual obligations',
#  'contribute',
#  'contribute business',
#  'contributing',
#  'contributor',
#  'contributor individually',
#  'control',
#  'control work',
#  'controls',
#  'controls quality',
#  'conversion',
#  'converted',
#  'converted permanent',
#  'convince',
#  'convince customers',
#  'coordinate subject',
#  'coordinating',
#  'coordination',
#  'copy',
#  'copy privacy',
#  'copy resume',
#  'core',
#  'corporate',
#  'corporations',
#  'correct',
#  'correctlyprepare',
#  'correctlyprepare presentations',
#  'cost benefit',
#  'cost effective',
#  'cost savings',
#  'costs',
#  'countries',
#  'country',
#  'cover',
#  'coverage',
#  'coverage asean3',
#  'covering',
#  'covers',
#  'create',
#  'create manage',
#  'create unique',
#  'creating',
#  'creating business',
#  'creating cross',
#  'creating developing',
#  'creating technical',
#  'creation',
#  'creation activities',
#  'creative',
#  'creative freedom',
#  'creativity',
#  'credibility',
#  'credibility oracle',
#  'criteria',
#  'critical',
#  'critical systems',
#  'critical thinking',
#  'crm',
#  'cross functional',
#  'cross functionally',
#  'cross platform',
#  'cs',
#  'cse1',
#  'cse1 solution',
#  'css',
#  'css3',
#  'css3 javascript',
#  'culture',
#  'culture believes',
#  'current employment',
#  'current expected',
#  'current salary',
#  'currently',
#  'currently looking',
#  'curriculum',
#  'curriculum vitae',
#  'customer able',
#  'customer base',
#  'customer business',
#  'customer experience',
#  'customer facing',
#  'customer needs',
#  'customer organization',
#  'customer projects',
#  'customer requirements',
#  'customer satisfaction',
#  'customer service',
#  'customer visits',
#  'customers buy',
#  'customers coordinate',
#  'customers executive',
#  'customers order',
#  'customers require',
#  'customization',
#  'customized',
#  'cutting',
#  'cutting edge',
#  'cv current',
#  'cv faster',
#  'cv ms',
#  'cv resume',
#  'cx',
#  'cx cse1',
#  'cx omc2',
#  'cyber',
#  'cyber security',
#  'cycle including',
#  'cycle sdlc',
#  'cycles',
#  'daily',
#  'dashboards',
#  'dashboards scorecards',
#  'data affiliates',
#  'data analysis',
#  'data analyst',
#  'data analysts',
#  'data analytical',
#  'data analytics',
#  'data anlaysis',
#  'data articulate',
#  'data business',
#  'data channel',
#  'data collection',
#  'data conduct',
#  'data connection',
#  'data conversion',
#  'data exploration',
#  'data extraction',
#  'data governance',
#  'data insights',
#  'data internal',
#  'data management',
#  'data managementexpertise',
#  'data migration',
#  'data mining',
#  'data modeling',
#  'data modelling',
#  'data models',
#  'data needs',
#  'data possess',
#  'data quality',
#  'data recommend',
#  'data science',
#  'data sets',
#  'data setsinterpret',
#  'data sources',
#  'data support',
#  'data team',
#  'data trends',
#  'data visualization',
#  'data warehouse',
#  'data warehousing',
#  'database',
#  'database data',
#  'database design',
#  'database management',
#  'databases',
#  'databases data',
#  'dataprotection',
#  'dataprotection kellyservices',
#  'datasets',
#  'date',
#  ...]

# %% [markdown]
# # k-means classification

# %%
#  classification

from sklearn.cluster import KMeans
num_clusters = 4
km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)
# Out:
# Wall time: 614 ms
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# # result interpretation

# %%
# build dataframe
clusters = km.labels_.tolist()
results = pd.DataFrame()
results['title'] = x
results['cluster'] = km.labels_
results
# Out:
#                        title  cluster
# 0        data analyst junior        1
# 1       data analyst senior         1
# 2           business analyst        1
# 3  software engineer  junior        0
# 4  software engineer  senior        0
# 5           software manager        2
# 6          software director        2
# 7            project manager        3
# 8              sales manager        3

# %%
# number of job titles per cluster 

results['cluster'].value_counts()
# Out:
# 1    3
# 3    2
# 2    2
# 0    2
# Name: cluster, dtype: int64

# %%
# job titles in each cluster

results.groupby(by='cluster').apply(lambda x:[','.join(x['title'])])
# Out:
# cluster
# 0    [software engineer  junior,software engineer  ...
# 1    [data analyst junior,data analyst senior ,busi...
# 2                 [software manager,software director]
# 3                      [project manager,sales manager]
# dtype: object

# %%
# Top keywords per cluster

print("Top keywords per cluster:")
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
order_centroids
terms = tfidf_vectorizer.get_feature_names()
for i in range(num_clusters):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :20]]
    print("Cluster {}: {}".format(i,' '.join(top_ten_words)))
# Out:
# Top keywords per cluster:
# Cluster 0: work location software engineer programming engineer solution engineers code web location address consulting platform real time application development design develop oracle scalable ai architecture cloud improve
# Cluster 1: analytics work location data analysis excel personal caed caed com mining view personal data analyst reports business requirements banking privacy policy data analyst location address policy privacy view larger
# Cluster 2: architecture leadership sap enterprise dynamics iot cloud solution vendor review business applications marketing architect objectives application development lead cyber strategic drive pay
# Cluster 3: risk ll ey area solution clients professional better risk management progress pmo certified consulting digital plan long pre sales budget project manager pmp
